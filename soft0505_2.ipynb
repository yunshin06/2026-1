# %%
# N x N 행렬의 모든 값을 0보다 크고 (N x N x 10) 보다 작은 임의의(random) 값으로 채워주는 함수
import random
N = int(input())
def random_matrix(n):
  matrix = []
  for i in range(n):
    row = []
    for j in range(n):
      row.append(random.randrange(1, (n*n*10)))
    matrix.append(row)
  return matrix
# Out:
# 5

# %%
# 행렬 N x N을 예쁘게 출력하는 함수
def print_matrix(matrix):
  n = len(matrix)
  for i in range(n):
    for j in range(n):
      print(f'{matrix[i][j]:5d}', end=' ')
    print()

# %%
# N x N 행렬의 전치 행렬을 구하는 프로그램
a = random_matrix(N)
trans = []
for i in range(N):
  row = []
  for j in range(N):
    row.append(a[j][i])
  trans.append(row)
print_matrix(trans)
# Out:
#   150   238    45   176   204
#    62   129   238   130   164
#   170    46    87    34   177
#   234   134   175   209   146
#   140    59   187   195    74
